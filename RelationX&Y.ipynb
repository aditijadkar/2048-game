# %% [markdown]
# <a href="https://colab.research.google.com/github/aditijadkar/2048-game/blob/main/RelationX%26Y.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)

# %%
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - loss: 35.5912
# Epoch 2/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 28.0072
# Epoch 3/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 22.0404
# Epoch 4/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 17.3459
# Epoch 5/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 13.6524
# Epoch 6/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 10.7464
# Epoch 7/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 8.4600
# Epoch 8/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 6.6610
# Epoch 9/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 5.2456
# Epoch 10/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 4.1319
# Epoch 11/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 3.2556
# Epoch 12/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 2.5661
# Epoch 13/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 2.0235
# Epoch 14/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.5965
# Epoch 15/500
# ...

# %%
# Convert the list to a NumPy array
prediction_input = np.array([10.0])
# Make the prediction
print(model.predict(prediction_input))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# [[31.002855]]

# %%
# Convert the list to a NumPy array
prediction_input = np.array([10.0])
# Make the prediction
print(model.predict(prediction_input))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[31.002855]]
